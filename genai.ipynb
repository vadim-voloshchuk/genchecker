# %%
import textwrap

import google.generativeai as genai

# %%
import cohere

co = cohere.Client(
    api_key="xa88h1He5s7PhBTMcnyCsaOiL6uIsB0rtMQjqW3k",
)

# %%
import docx

def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
main_text = getText("Гибкие методологии Управление IT-проектами 29 апреля 1.docx")
main_text
# Out:
# 'МИНИСТЕРСТВО НАУКИ И ВЫСШЕГО ОБРАЗОВАНИЯ\nРОССИЙСКОЙ ФЕДЕРАЦИИ\nФедеральное государственное автономное\nобразовательное учреждение высшего образования\n«ЮЖНЫЙ ФЕДЕРАЛЬНЫЙ УНИВЕРСИТЕТ»\nИнженерно-технологическая академия\n\n\n\n\n\n\n\nА. Н. САМОЙЛОВ\nД. А. БЕСПАЛОВ\nА. В. ТЫЧИНСКИЙ\nА. В. КОЗЛОВСКИЙ\nЭ. В. МЕЛЬНИК\n\n\n\n\n\n\n\nГИБКИЕ МЕТОДОЛОГИИ УПРАВЛЕНИЕ IT-ПРОЕКТАМИ\n\n\n\n\n\n\nУчебное пособие\n\n\n\n\n\n\n\n\nРостов-на-Дону – Таганрог\nИздательство Южного федерального университета\n2024\nУДК 004.451(075.8)\nББК 32.973я73\nО 609\nПечатается по решению кафедры вычислительной техники\nИнститута компьютерных технологий и информационной безопасности\nЮжного федерального университета\n(протокол № 7 от 06.03.2024 г.)\nРецензенты:\nпрофессор кафедры физико-математических основ инженерного образования \nИнженерно-технологической\nакадемии Южного федерального университета,\nдоктор технических наук, профессор Г. В. Куповых;\n\nВедущий научный сотрудник Южного научного центра Российской 
# ...

# %%
readme = open('инструкция.txt', 'r', encoding="utf-8").read()
readme
# Out:
# '# Instruction\nТы выступаешь в роли человека с опытом переписывания генерированного текста на человеческий(НЕ СГЕНЕРИРОВАННЫЙ) 15 лет.\nСам текст должен быть обезличенным, ты не описываешь свой опыт.\nСтарайся сохранить исходный объем текста в процессе переписывания.\nСтарайся сохранить исходную структуру документа в процессе переписывания.\n\n# Task\nПерепиши все куски текста с подозрением на генерацию так, чтобы она не прослеживалось.\n# Output format\nПереписанный контекст, в котором либо генерация не прослеживается, либо прослеживается минимально. \nНичего кроме переписанного фрагмента выводить не надо.\n\n# Data context'

# %%
import os
warning_pieces = os.listdir("source_text")
warning_pieces
# Out:
# ['8', '9']

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY="AIzaSyA-ndk8GaYzCbYk1KnZkjrFpQOoMPes2gk"

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-1.5-pro-latest')

# %%
for raw_log in warning_pieces:
    piece_problem = open(f"source_text/{raw_log}", 'r', encoding="utf-8").read()
    messages = [
    {'role':'user',
     'parts': f"""
    {readme}
    Общий контекст:
    {main_text}

    Сгенерированный фрагмент:
    {piece_problem}
    """}
    ]

    response = model.generate_content(messages)
    file = open(f'rewrited/{raw_log}', 'w', encoding="utf-8")
    file.write(response.text)
    file.close()

# %%
chat = co.chat(
    message="Мяу!",
    model="command"
)

print(chat.text)
